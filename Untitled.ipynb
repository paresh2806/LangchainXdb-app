# %%
print('helloo')
# Out:
# helloo

# %%
db_user = "root"
db_password = "admin"
db_host = "localhost:3306"
db_name = "chinook"
db_name2 = "classicmodels"

# %%
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = ""

# %%
from langchain_community.utilities.sql_database import SQLDatabase
db = SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")
db_cars= SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name2}")

# %%
print(db.dialect)
# Out:
# mysql

# %%
print(db.get_usable_table_names())
# Out:
# ['customers', 'employees', 'offices', 'orderdetails', 'orders', 'payments', 'productlines', 'products']

# %%
print(db.table_info)
# Out:
# CREATE TABLE album (
# 	`AlbumId` INTEGER NOT NULL,
# 	`Title` VARCHAR(160) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`ArtistId` INTEGER NOT NULL,
# 	PRIMARY KEY (`AlbumId`),
# 	CONSTRAINT `FK_AlbumArtistId` FOREIGN KEY(`ArtistId`) REFERENCES artist (`ArtistId`)
# )ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from album table:
# AlbumId	Title	ArtistId
# 1	For Those About To Rock We Salute You	1
# 2	Balls to the Wall	2
# 3	Restless and Wild	2
# */
#
#
# CREATE TABLE artist (
# 	`ArtistId` INTEGER NOT NULL,
# 	`Name` VARCHAR(120) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	PRIMARY KEY (`ArtistId`)
# )ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from artist table:
# ArtistId	Name
# 1	AC/DC
# 2	Accept
# 3	Aerosmith
# */
#
#
# CREATE TABLE customer (
# 	`CustomerId` INTEGER NOT NULL,
# 	`FirstName` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# ...

# %%
from langchain.chains import create_sql_query_chain
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
generate_query = create_sql_query_chain(llm, db)
query = generate_query.invoke({"question": "what is price of `1968 Ford Mustang`"})
# "what is price of `1968 Ford Mustang`"
print(query)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[23], line 4
#       1 from langchain.chains import create_sql_query_chain
#       2 from langchain_openai import ChatOpenAI
# ----> 4 llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
#       5 generate_query = create_sql_query_chain(llm, db)
#       6 query = generate_query.invoke({"question": "what is price of `1968 Ford Mustang`"})
#
# File D:\Paresh\Python\LangchainXdb-app\venv\lib\site-packages\langchain_core\load\serializable.py:120, in Serializable.__init__(self, **kwargs)
#     119 def __init__(self, **kwargs: Any) -> None:
# --> 120     super().__init__(**kwargs)
#     121     self._lc_kwargs = kwargs
#
# File D:\Paresh\Python\LangchainXdb-app\venv\lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
# ...
